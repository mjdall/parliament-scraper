# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

sys.path.append(os.path.join(os.path.abspath(""), ".."))

# %%
from parliament.utils import load_json
from parliament.tags import initial_parse

report_links = load_json("../output/meta/all_report_links.json")

test_report = report_links[6]

preface, html_tags, tag_names, tags_flat = initial_parse(
    test_report[0], test_report[1])

tag_names[4]
# Out:
# ['Speech', 'a', 'a', 'a', 'a', 'a', 'EndOfSection']

# %%
def add_speeches_or_debates(tag, debates=True):
    tag_ss = "debates" if debates else "speeches"
    ss = tag.get(tag_ss, [])
    if not ss:
        if debates:
            return add_speeches_or_debates(tag, debates=False)
        return None

    results = { tag_ss: [], "class": tag["class"] }
    for _tag in ss:
        tag_class = _tag["class"]
        has_speeches = bool(_tag.get("speeches", []))
        if debates and has_speeches:
            speeches = add_speeches_or_debates(_tag, debates=False)
            assert speeches is not None
            tag_class = { "class": _tag["class"], "speeches": speeches }
        results[tag_ss].append(tag_class)
    return results


output = []

for tag in parsed[5]:
    current_class = tag["class"]
    if "debates" in tag or "speeches" in tag:
        current_class = add_speeches_or_debates(tag)
    output.append(current_class)
# pprint(output)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25932/419926148.py in <module>
#      21 output = []
#      22
# ---> 23 for tag in parsed[5]:
#      24     current_class = tag["class"]
#      25     if "debates" in tag or "speeches" in tag:
#
# NameError: name 'parsed' is not defined

# %%
from parliament.scraper import parse_all_html
from pprint import pprint

parsed = parse_all_html(html_tags)
pprint(parsed[5])
# Out:
# [{'class': 'BillDebate',
#   'debates': [{'class': 'SubDebate',
#                'speeches': [{'class': 'Speech',
#                              'date': '29/06/2021',
#                              'speaker': 'Hon ANDREW LITTLE',
#                              'speaker_subtitle': 'Minister for Treaty of '
#                                                  'Waitangi Negotiations',
#                              'tag_id': 'Speech',
#                              'text': 'I present a legislative statement on the '
#                                      'Ahuriri Hapu Claims Settlement Bill.',
#                              'time': '16:41:00'},
#                             {'class': 'Intervention',
#                              'speaker': 'ASSISTANT SPEAKER',
#                              'speaker_subtitle': 'Hon Jacqui Dean',
#                              'tag_id': 'Interjection',
#                              'text': 'That legislative statement is published '
# ...

# %%
flat = [[tag.get("class", tag) for tag in section] for section in parsed]

pprint(flat)
# Out:
# [['BeginningOfDay', 'a', 'Debatealone', 'Speech', 'a'],
#  ['Debate'],
#  ['Speech',
#   'Speech',
#   'Speech',
#   'Speech',
#   'Speech',
#   'Speech',
#   'Speech',
#   'Speech',
#   'Speech',
#   'Speech'],
#  ['QOA',
#   'QType',
#   'SubsQuestion',
#   'SubsQuestion',
#   'SubsQuestion',
#   'SubsQuestion',
#   'SubsQuestion',
#   'SubsQuestion',
#   'SubsQuestion',
#   'SubsQuestion',
#   'SubsQuestion',
#   'SubsQuestion',
#   'SubsQuestion',
#   'SubsQuestion',
#   'QOAEnd'],
#  ['Debate'],
#  ['BillDebate'],
#  ['BillDebate'],
#  ['MarginHeading',
#   'Speech',
#   'Speech',
#   'a',
#   'a',
#   'a',
#   'Speech',
#   'Speech',
#   'Speech',
#   'Speech',
#   'a',
#   'Interjection',
#   'ContinueSpeech',
#   'Interjection',
#   'ContinueSpeech',
#   'a',
#   'Speech',
#   'Speech',
#   'VoteReason',
#   'VoteCount',
#   'VoteText',
#   'VoteCount',
#   'VoteText',
#   'VoteResult',
#   'VoteReason',
#   'VoteCount',
#   'VoteText',
#   'VoteCount',
#   'VoteText',
# ...

# %%
pprint(parsed[4])
# Out:
# [{'class': 'QOA', 'tag_id': 'QAndA', 'text': 'ORAL QUESTIONS'},
#  {'class': 'QType', 'tag_id': 'Question', 'text': 'QUESTIONS TO MINISTERS'},
#  {'class': 'SubsQuestion',
#   'speaker': '1. Dr SHANE RETI',
#   'speaker_subtitle': 'Deputy Leader—National',
#   'tag_id': 'Question',
#   'text': 'Does he stand by all of his statements and actions?'},
#  {'class': 'SubsAnswer',
#   'date': '24/06/2021',
#   'speaker': 'Hon ANDREW LITTLE',
#   'speaker_subtitle': 'Minister of Health',
#   'tag_id': 'Answer',
#   'text': 'Yes.',
#   'time': '14:13:47'},
#  {'class': 'SupQuestion',
#   'speaker': 'Dr Shane Reti',
#   'tag_id': 'Question',
#   'text': 'Has he received any advice from health officials that restructuring '
#           'the health system during a pandemic could negatively impact our '
#           'ability to respond to a coronavirus outbreak?'},
#  {'class': 'SupAnswer',
#   'speaker': 'Hon ANDREW LITTLE',
#   'tag_id': 'Answer',
#   'text': 'No.'},
# ...

# %%
structure = [(i, tag["class"]) for i, section in enumerate(parsed) for tag in section]

pprint(structure)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4304/2657378624.py in <module>
# ----> 1 structure = [(i, tag["class"]) for i, section in enumerate(parsed) for tag in section]
#       2
#       3 pprint(structure)
#
# ~\AppData\Local\Temp/ipykernel_4304/2657378624.py in <listcomp>(.0)
# ----> 1 structure = [(i, tag["class"]) for i, section in enumerate(parsed) for tag in section]
#       2
#       3 pprint(structure)
#
# KeyError: 'class'

# %%
from parliament.tags import parse_tags_to_dict
from pprint import pprint

pprint(parse_tags_to_dict(html_tags)[3:10])
# Out:
# [{'class': 'Speech',
#   'date': '10/06/2021',
#   'speaker': 'DEPUTY SPEAKER',
#   'tag_id': 'Note',
#   'text': 'E te Atua kaha rawa, ka tuku whakamoemiti atu matou, mo nga karakia '
#           'kua waihotia mai ki runga i a matou. Ka waiho i o matou panga '
#           'whaiaro katoa ki te taha. Ka mihi matou ki te Kuini, me te inoi atu '
#           'mo te arahitanga i roto i o matou whakaaroarohanga, kia mohio ai, '
#           'kia whakaiti ai ta matou whakahaere i nga take o te Whare nei, mo '
#           'te oranga, te maungarongo, me te aroha o Aotearoa. Amene.',
#   'time': '14:00:18'},
#  {'class': 'a',
#   'tag_id': 'Note',
#   'text': '[Almighty God, we give thanks for the blessings which have been '
#           'bestowed on us. Laying aside all personal interests, we acknowledge '
#           'the Queen, and pray for guidance in our deliberations, that we may '
#           'conduct the affairs of this House with wisdom and humility, for the '
# ...

# %%
from parliament.structure import parse_tag_structure
from pprint import pprint

new_groupings = parse_tag_structure(tags_flat)

pprint(new_groupings)
# Out:
# ('Current Group: BeginningOfDay    Current Tag: BeginningOfDay    Previous '
#  'Tag: None    Was EOS: False')
# Coudnt find: `Ending`, returning Note
# [['a', 'Debatealone', 'Speech', 'a', 'EndOfSection'],
#  ['Debate',
#   'SubDebate',
#   'Speech',
#   'Interjection',
#   'ContinueSpeech',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'EndOfSection',
#   'Speech',
#   'a',
#   'a',
#   'a',
#   'a',
#   'EndOfSection',
#   'Speech',
#   'a',
#   'a',
#   'EndOfSection',
#   'Speech',
#   'a',
#   'a',
#   'a',
#   'IndentMarginalone',
#   'EndOfSection'],
#  ['Debatealone', 'Speech', 'EndOfSection'],
#  ['Debatealone', 'Speech', 'Speech', 'a', 'a', 'a', 'a', 'a', 'EndOfSection'],
#  ['QOA',
#   'QType',
#   'SubsQuestion',
#   'SubsAnswer',
#   'SupQuestion',
#   'SupAnswer',
#   'SupQuestion',
#   'SupAnswer',
#   'SupQuestion',
#   'SupAnswer',
#   'SupQuestion',
#   'SupAnswer',
#   'SupQuestion',
#   'SupAnswer',
#   'SupQuestion',
# ...
